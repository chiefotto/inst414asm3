# %%
import pandas as pd
import json
import numpy as np
import math
import sklearn
from scipy.spatial import distance
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import DistanceMetric
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import jaccard_score

df = pd.read_csv('Fifa 23 Players Data.csv')

df = df.set_index('Full Name')
df
# Out:
#                           Known As  Overall  Potential  Value(in Euro)  \
# Full Name
# Lionel Messi              L. Messi       91         91        54000000
# Karim Benzema           K. Benzema       91         91        64000000
# Robert Lewandowski  R. Lewandowski       91         91        84000000
# Kevin De Bruyne       K. De Bruyne       91         91       107500000
# Kylian Mbappé            K. Mbappé       91         95       190500000
# ...                            ...      ...        ...             ...
# Darren Collins          D. Collins       47         56          110000
# Dejiang Yang          Yang Dejiang       47         57           90000
# Liam Mullan              L. Mullan       47         67          130000
# Daithí McCallion      D. McCallion       47         61          100000
# Nabin Rabha               N. Rabha       47         50           60000
#
#                    Positions Played Best Position          Nationality  \
# Full Name
# Lionel Messi                     RW           CAM            Argentina
# Karim Benzema                 CF,ST            CF               France
# Robert Lewandowski               ST            ST               Poland
# Kevin De Bruyne              CM,CAM            CM              Belgium
# Kylian Mbappé                 ST,LW            ST               France
# ...                             ...           ...                  ...
# Darren Collins                ST,RM           CAM  Republic of Ireland
# Dejiang Yang                    CDM           CDM             China PR
# Liam Mullan                      CM            RM     Northern Ireland
# Daithí McCallion                 CB            CB  Republic of Ireland
# Nabin Rabha                      LB            LB                India
#
#                                                           Image Link  Age  \
# Full Name
# Lionel Messi        https://cdn.sofifa.net/players/158/023/23_60.png   35
# Karim Benzema       https://cdn.sofifa.net/players/165/153/23_60.png   34
# Robert Lewandowski  https://cdn.sofifa.net/players/188/545/23_60.png   33
# Kevin De Bruyne     https://cdn.sofifa.net/players/192/985/23_60.png   31
# Kylian Mbappé       https://cdn.sofifa.net/players/231/747/23_60.png   23
# ...                                                              ...  ...
# Darren Collins      https://cdn.sofifa.net/players/243/725/23_60.png   21
# Dejiang Yang        https://cdn.sofifa.net/players/261/933/23_60.png   17
# Liam Mullan         https://cdn.sofifa.net/players/267/823/23_60.png   18
# Daithí McCallion    https://cdn.sofifa.net/players/267/824/23_60.png   17
# Nabin Rabha         https://cdn.sofifa.net/players/261/424/23_60.png   25
#
#                     Height(in cm)  ...  LM Rating  CM Rating  RM Rating  \
# Full Name                          ...
# Lionel Messi                  169  ...         91         88         91
# Karim Benzema                 185  ...         89         84         89
# Robert Lewandowski            185  ...         86         83         86
# Kevin De Bruyne               181  ...         91         91         91
# Kylian Mbappé                 182  ...         92         84         92
# ...                           ...  ...        ...        ...        ...
# Darren Collins                174  ...         50         44         50
# Dejiang Yang                  175  ...         45         45         45
# Liam Mullan                   170  ...         52         49         52
# Daithí McCallion              178  ...         33         33         33
# Nabin Rabha                   176  ...         44         40         44
#
#                    LWB Rating  CDM Rating  RWB Rating LB Rating CB Rating  \
# Full Name
# Lionel Messi               67          66          67        62        53
# Karim Benzema              67          67          67        63        58
# Robert Lewandowski         67          69          67        64        63
# Kevin De Bruyne            82          82          82        78        72
# Kylian Mbappé              70          66          70        66        57
# ...                       ...         ...         ...       ...       ...
# Darren Collins             41          38          41        40        36
# Dejiang Yang               47          48          47        49        49
# Liam Mullan                46          44          46        46        42
# Daithí McCallion           44          42          44        47        49
# Nabin Rabha                46          43          46        47        47
#
#                    RB Rating  GK Rating
# Full Name
# Lionel Messi              62         22
# Karim Benzema             63         21
# Robert Lewandowski        64         22
# Kevin De Bruyne           78         24
# Kylian Mbappé             66         21
# ...                      ...        ...
# Darren Collins            40         15
# Dejiang Yang              49         15
# Liam Mullan               46         17
# Daithí McCallion          47         15
# Nabin Rabha               47         19
#
# [18539 rows x 88 columns]

# %%
# normilization and player attribvute columns established (striker attributes)

striker_attr = ['Height(in cm)', 'Pace Total','Shooting Total','Weak Foot Rating']

striker_df=(df[striker_attr]-df[striker_attr].min())/(df[striker_attr].max()-df[striker_attr].min())

striker_df
# Out:
#                     Height(in cm)  Pace Total  Shooting Total  \
# Full Name
# Lionel Messi             0.274510    0.768116        0.960526
# Karim Benzema            0.588235    0.753623        0.947368
# Robert Lewandowski       0.588235    0.681159        0.986842
# Kevin De Bruyne          0.509804    0.666667        0.947368
# Kylian Mbappé            0.529412    1.000000        0.960526
# ...                           ...         ...             ...
# Darren Collins           0.372549    0.579710        0.421053
# Dejiang Yang             0.392157    0.391304        0.276316
# Liam Mullan              0.294118    0.521739        0.315789
# Daithí McCallion         0.450980    0.347826        0.105263
# Nabin Rabha              0.411765    0.478261        0.171053
#
#                     Weak Foot Rating
# Full Name
# Lionel Messi                    0.75
# Karim Benzema                   0.75
# Robert Lewandowski              0.75
# Kevin De Bruyne                 1.00
# Kylian Mbappé                   0.75
# ...                              ...
# Darren Collins                  0.50
# Dejiang Yang                    0.50
# Liam Mullan                     0.50
# Daithí McCallion                0.50
# Nabin Rabha                     0.50
#
# [18539 rows x 4 columns]

# %%
ronaldo = 'C. Ronaldo dos Santos Aveiro'
ronaldo_stats = striker_df.loc[ronaldo]

gen_stats = striker_df[striker_df.index!=ronaldo]


ronaldo_stats = ronaldo_stats.values.reshape(1,-1)

ronaldo_stats

striker_df['Cosine_Similarity'] = striker_df.apply(lambda row: cosine_similarity(row.values.reshape(1, -1), ronaldo_stats)[0, 0], axis=1)



striker_df_sorted = striker_df.sort_values(by='Cosine_Similarity', ascending=False)

top = striker_df_sorted.head(11)
top
# Out:
#                               Height(in cm)  Pace Total  Shooting Total  \
# Full Name
# C. Ronaldo dos Santos Aveiro       0.627451    0.768116        1.000000
# Karim Benzema                      0.588235    0.753623        0.947368
# Robert Lewandowski                 0.588235    0.681159        0.986842
# Ciro Immobile                      0.588235    0.826087        0.934211
# Alfredo Talavera                   0.607843    0.753623        0.868421
# Marc-André ter Stegen              0.627451    0.840580        0.907895
# Romelu Lukaku                      0.705882    0.753623        0.907895
# Yann Sommer                        0.549020    0.724638        0.855263
# Leon Goretzka                      0.666667    0.724638        0.868421
# Duván Zapata                       0.666667    0.724638        0.868421
# Mehdi Taremi                       0.607843    0.710145        0.842105
#
#                               Weak Foot Rating  Cosine_Similarity
# Full Name
# C. Ronaldo dos Santos Aveiro              0.75           1.000000
# Karim Benzema                             0.75           0.999659
# Robert Lewandowski                        0.75           0.999082
# Ciro Immobile                             0.75           0.998757
# Alfredo Talavera                          0.75           0.998309
# Marc-André ter Stegen                     0.75           0.998086
# Romelu Lukaku                             0.75           0.997974
# Yann Sommer                               0.75           0.997730
# Leon Goretzka                             0.75           0.997711
# Duván Zapata                              0.75           0.997711
# Mehdi Taremi                              0.75           0.997548

# %%
passing_attr = ['Passing Total','Crossing','Curve','LongPassing','Short Passing']
passing_df = (df[passing_attr]-df[passing_attr].min())/(df[passing_attr].max()-df[passing_attr].min())

modric = 'Luka Modrić'
modric_stats = passing_df.loc[modric]
modric_stats = modric_stats.values.reshape(1,-1)



def jaccard_similarity(p1,p2):
    intersection = len(set(p1)& set(p2))
    union = len(set(p1)| set(p2))
    return intersection / union



passing_df['Jaccard_Similarity'] = passing_df.apply(lambda row: jaccard_similarity(str(row.values), str(modric_stats)), axis=1)


passing_df = passing_df.sort_values(by='Jaccard_Similarity', ascending=False)

top_10_closest = passing_df.head(10)

top_10_closest
# Out:
#                     Passing Total  Crossing     Curve  LongPassing  \
# Full Name
# Lionel Messi             0.955882  0.886364  1.000000     0.964286
# Julián Figueroa          0.485294  0.613636  0.356322     0.619048
# Agustín Chopitea         0.411765  0.738636  0.540230     0.654762
# Nathan Fogaça            0.235294  0.227273  0.356322     0.238095
# Callum Paterson          0.470588  0.625000  0.390805     0.559524
# Sam Nicholson            0.470588  0.590909  0.528736     0.523810
# Jordan Tunnicliffe       0.294118  0.250000  0.252874     0.559524
# Amir Saipi               0.544118  0.090909  0.091954     0.202381
# Ben Heneghan             0.235294  0.159091  0.149425     0.511905
# Romario Benzar           0.544118  0.670455  0.689655     0.595238
#
#                     Short Passing  Jaccard_Similarity
# Full Name
# Lionel Messi             0.975904                 1.0
# Julián Figueroa          0.662651                 1.0
# Agustín Chopitea         0.445783                 1.0
# Nathan Fogaça            0.518072                 1.0
# Callum Paterson          0.578313                 1.0
# Sam Nicholson            0.590361                 1.0
# Jordan Tunnicliffe       0.566265                 1.0
# Amir Saipi               0.096386                 1.0
# Ben Heneghan             0.554217                 1.0
# Romario Benzar           0.614458                 1.0

# %%
messi_attr = ['Sprint Speed','Short Passing','Dribbling','BallControl','Acceleration','Balance']

messi_df = (df[messi_attr]-df[messi_attr].min())/(df[messi_attr].max()-df[messi_attr].min())




messi = 'Lionel Messi'

messi_stats = messi_df.loc[messi]
messi_stats = messi_stats.values.reshape(1,-1)



messi_df['Eucledian_Distance'] = euclidean_distances((messi_df.values), (messi_stats))


messi_df = messi_df.sort_values(by='Eucledian_Distance', ascending=True)

top_10_closest = messi_df.head(11)

top_10_closest
# Out:
#                                 Sprint Speed  Short Passing  Dribbling  \
# Full Name
# Lionel Messi                        0.743902       0.975904   1.000000
# Bernardo Mota Carvalho e Silva      0.682927       0.951807   0.967391
# Paulo Dybala                        0.743902       0.915663   0.945652
# Lorenzo Insigne                     0.804878       0.891566   0.945652
# Phil Foden                          0.768293       0.903614   0.913043
# Jadon Sancho                        0.768293       0.915663   0.956522
# Iker Muniain Goñi                   0.768293       0.903614   0.913043
# Pedro González López                0.743902       0.927711   0.913043
# Dries Mertens                       0.719512       0.891566   0.923913
# Riyad Mahrez                        0.756098       0.879518   0.956522
# Nabil Fekir                         0.780488       0.879518   0.934783
#
#                                 BallControl  Acceleration   Balance  \
# Full Name
# Lionel Messi                       0.988764      0.879518  1.000000
# Bernardo Mota Carvalho e Silva     0.966292      0.843373  0.960000
# Paulo Dybala                       0.988764      0.843373  0.933333
# Lorenzo Insigne                    0.955056      0.879518  0.986667
# Phil Foden                         0.966292      0.867470  0.946667
# Jadon Sancho                       0.932584      0.843373  0.920000
# Iker Muniain Goñi                  0.921348      0.843373  0.986667
# Pedro González López               0.932584      0.819277  0.933333
# Dries Mertens                      0.932584      0.819277  0.960000
# Riyad Mahrez                       0.955056      0.843373  0.906667
# Nabil Fekir                        0.910112      0.891566  0.946667
#
#                                 Eucledian_Distance
# Full Name
# Lionel Messi                              0.000000
# Bernardo Mota Carvalho e Silva            0.093666
# Paulo Dybala                              0.111056
# Lorenzo Insigne                           0.122876
# Phil Foden                                0.129910
# Jadon Sancho                              0.130295
# Iker Muniain Goñi                         0.139324
# Pedro González López                      0.145305
# Dries Mertens                             0.147926
# Riyad Mahrez                              0.149943
# Nabil Fekir                               0.155105
